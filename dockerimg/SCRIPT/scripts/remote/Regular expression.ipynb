# %%
import re
str='''ami-id: ami-cd0f5cb6
ami-launch-index: 0
ami-manifest-path: (unknown)
ancestor-ami-ids: unavailable
availability-zone: us-east-1d
block-device-mapping: ami
root
instance-action: none
instance-id: i-0950bb61f032de690
instance-type: t2.micro
local-hostname: ip-172-31-26-103.ec2.internal
local-ipv4: 172.31.26.103
kernel-id: unavailable
mac: unavailable
profile: default-hvm
product-codes: unavailable
public-hostname: ec2-34-203-13-231.compute-1.amazonaws.com
public-ipv4: 34.203.13.231
public-keys: ['ssh-rsa  as0']
ramdisk-id: unavailable
reserveration-id: unavailable
security-groups: default
user-data: unavailable'''

obj=re.search(r'instance-id: (.*)\n',str)
print(obj.group(1))
# Out:
# i-0950bb61f032de690

# %%
import re
str='''y-cruncher v0.7.5 Build 9480

Detecting Environment...

CPU Vendor:
    AMD         = No
    Intel       = Yes

OS Features:
  * 64-bit      = Yes
  * OS AVX      = Yes
  * OS AVX512   = No

Hardware Features:
    MMX         = Yes
  * x64         = Yes
  * ABM         = Yes
    RDRAND      = Yes
    RDSEED      = No
    BMI1        = Yes
  * BMI2        = Yes
  * ADX         = No
    MPX         = No
    PREFETCHW   = No
    PREFETCHWT1 = No

SIMD: 128-bit
  * SSE         = Yes
  * SSE2        = Yes
  * SSE3        = Yes
  * SSSE3       = Yes
    SSE4a       = No
  * SSE4.1      = Yes
  * SSE4.2      = Yes
    AES-NI      = Yes
    SHA         = No

SIMD: 256-bit
  * AVX         = Yes
  * XOP         = No
  * FMA3        = Yes
  * FMA4        = No
  * AVX2        = Yes

SIMD: 512-bit
  * AVX512-F         = No
    AVX512-CD        = No
    AVX512-PF        = No
    AVX512-ER        = No
  * AVX512-VL        = No
  * AVX512-BW        = No
  * AVX512-DQ        = No
  * AVX512-IFMA      = No
  * AVX512-VBMI      = No

Alright Intel, how many drinks have you had tonight?
    AVX512-VPOPCNTDQ = No
    AVX512-4FMAPS    = No
    AVX512-4VNNIW    = No
    AVX512-VBMI2     = No
    AVX512-GFNI      = No
    AVX512-VAES      = No
    AVX512-VPCLMUL   = No
    AVX512-VNNI      = No
    AVX512-BITALG    = No


Auto-Selecting: 13-HSW ~ Airi

/home/ubuntu/CPU_test/y-cruncher v0.7.5.9480-static/Binaries/13-HSW ~ Airi


Launching y-cruncher...
================================================================



Insufficient permissions to set thread priority. Please retry as root.

Further messages for this warning will be suppressed.

Checking processor/OS features...

Required Features:
    x64, ABM, BMI1, BMI2,
    SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2,
    AVX, FMA3, AVX2



Parsing Core -> Handle Mappings...
    Cores:  0 

Parsing NUMA -> Core Mappings...
    Node  0:  0 


y-cruncher v0.7.5 Build 9480                ( www.numberworld.org )
Copyright 2008-2019 Alexander J. Yee      ( a-yee@u.northwestern.edu )

Distribute Freely - Please report any bugs.

Tuning:  Linux/13-HSW ~ Airi  -  Haswell (x64 AVX2)


  0         Benchmark Pi  (all in ram)
  1         Component Stress Tester
  2         Run I/O Performance Analysis

  3         Custom Compute a Constant
                -   Compute other constants (e, Golden Ratio, etc...)
                -   Choose your own settings (use disk for large computations)

  4         BBP Digit Extractor for Pi
  5         Digit Viewer

  6         Advanced Options
  7         About

Enter your choice:
option: 
Benchmark Pi:



Available Memory:    681 MiB

Option      Decimal Digits          Approx. Memory Needed

  1             25,000,000                 220 MiB
  2             50,000,000                 345 MiB
  3            100,000,000                 585 MiB
  4            250,000,000                1.28 GiB
  5            500,000,000                2.46 GiB
  6          1,000,000,000                4.81 GiB
  7          2,500,000,000                11.6 GiB
  8          5,000,000,000                23.1 GiB
  9         10,000,000,000                46.2 GiB
 10         25,000,000,000                 116 GiB
 11         50,000,000,000                 231 GiB
 12        100,000,000,000                 463 GiB
 13        250,000,000,000                1.13 TiB
 14        500,000,000,000                2.26 TiB
 15      1,000,000,000,000                4.72 TiB
 16      2,500,000,000,000                11.5 TiB

  0     I prefer SuperPi sizes... (1M, 2M, 4M...)

option: 
This process does not have "CAP_IPC_LOCK". Page locking will not be possible.
Please run y-cruncher with elevation to enable page locking.

Constant:   Pi
Algorithm:  Chudnovsky Formula

Decimal Digits:       25,000,000
Hexadecimal Digits:   Disabled

Computation Mode:     Ram Only
Multi-Threading:      None (No Multi-threading)  ->  1 / ?

Start Time: Mon Apr 23 05:54:06 2018

Working Memory...   122 MiB  (spread: ?)
Twiddle Tables...   102 MiB  (spread: ?)

Begin Computation:

Summing Series...  1,762,846 terms

                                                                               
Summing: 0%  ( 22 )  -> ( 31,300 )
                                                                               
Summing: 17%  ( 4 )  -> ( 4,310,164 )
                                                                               
Summing: 24%  ( 3 ) ( 6,083,272 )
                                                                               
Summing: 34%  ( 2 ) ( 8,596,724 )
                                                                               
Summing: 48%  ( 1 ) -  ( 6,087,318 )
                                                                               
Summing: 69%  ( 0 ) 1 -> ( 8,656,316 )
                                                                               
Summing: 69%  ( 0 ) ( 17,312,703 )
                                                                               
Time:    7.881 seconds  ( 0.131 minutes )
Division...

                                                                               
Time:    0.541 seconds  ( 0.009 minutes )
InvSqrt...

                                                                               
Iterating: 00000000000000000 - 0S - ( 116 )
                                                                               
Time:    0.310 seconds  ( 0.005 minutes )
Final Multiply...

                                                                               
Time:    0.240 seconds  ( 0.004 minutes )

Pi:  8.973 seconds  ( 0.150 minutes )

Base Converting:

                                                                               
Time:    0.873 seconds  ( 0.015 minutes )

Writing Decimal Digits:   25,000,000  digits written

Start Time: Mon Apr 23 05:54:06 2018
End Time:   Mon Apr 23 05:54:16 2018

Total Computation Time:     9.845 seconds  ( 0.164 minutes )
Start-to-End Wall Time:     10.013 seconds  ( 0.167 minutes )

CPU Utilization:           99.84 %  +    0.00 % kernel overhead
Multi-core Efficiency:     99.84 %  +    0.00 % kernel overhead

Last Digits:  Pi
3803750790 9491563108 2381689226 7224175329 0045253446  :  24,999,950
0786411592 4597806944 2455112852 2554677483 6191884322  :  25,000,000

Spot Check: Good through 25,000,000

Version:              0.7.5.9480 (Linux/13-HSW ~ Airi)
Processor(s):         Intel(R) Xeon(R) CPU E5-2676 v3 @ 2.40GHz
Topology:             1 thread / 1 core / 1 socket / 1 NUMA node
Usable Memory:        1,038,872,576 ( 991 MiB)
CPU Base Frequency:   2,400,086,928 Hz

Validation File: Pi - 20180423-055416.txt'''
str=str.split('\n')
for line in str:
    if line.find('Available Memory:')!=-1:
        obj=re.search(r'(\d* \w*?B)',line)
print(obj.group(1))
# Out:
# 681 MiB

# %%
import re
line='123'
obj = re.search(r'(\d+)',line)
print(obj.group(1))
# Out:
# 123

# %%
import os
dir=os.listdir()
print(dir)
# Out:
# ['run.py', '.DS_Store', '__pycache__', 'experiment.py', 'Regular expression.ipynb', '.ipynb_checkpoints', 'data', 'const.py', 'developing parsing.py.ipynb']

# %%
dic=list([('a',2),('b','2')])
print(dic[0,0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-34b8132a3f4c> in <module>()
#       1 dic=list([('a',2),('b','2')])
# ----> 2 print(dic[0,0])
#
# TypeError: list indices must be integers or slices, not tuple
