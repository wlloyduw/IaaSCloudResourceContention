# %%
sysbench <- read.table("./sysbench-noIdle-11-07-2019 .csv", sep=",", header=TRUE)
head(sysbench)
# Out:
#   experimentID setId instanceID          instanceType wallTime
# 1 1573168503-0 0     i-00425c78c8efcd2bd m5d.large    9.063212
# 2 1573168503-0 0     i-00425c78c8efcd2bd m5d.large    9.046827
# 3 1573168503-0 0     i-00425c78c8efcd2bd m5d.large    9.049040
# 4 1573168503-0 0     i-00425c78c8efcd2bd m5d.large    9.073480
# 5 1573168503-0 0     i-00425c78c8efcd2bd m5d.large    9.056286
# 6 1573168503-0 0     i-00425c78c8efcd2bd m5d.large    9.042144
#   testOption
# 1 --test=cpu --cpu-max-prime=2000000 --num-threads=2 --max-requests=10 run
# 2 --test=cpu --cpu-max-prime=2000000 --num-threads=2 --max-requests=10 run
# 3 --test=cpu --cpu-max-prime=2000000 --num-threads=2 --max-requests=10 run
# 4 --test=cpu --cpu-max-prime=2000000 --num-threads=2 --max-requests=10 run
# 5 --test=cpu --cpu-max-prime=2000000 --num-threads=2 --max-requests=10 run
# 6 --test=cpu --cpu-max-prime=2000000 --num-threads=2 --max-requests=10 run
#   per.request.avg.time total.time thread.num
# ...

# %%
temp_vm_id <- subset(sysbench, subset=instanceID!="")
vm_id <- factor(temp_vm_id$instanceID)

#table(vm_id)
vm_ids <- as.integer(vm_id)
print(min(vm_ids))
print(max(vm_ids))
levels(vm_id)
# Out:
# [1] 1
# [1] 48
#  [1] "i-00425c78c8efcd2bd" "i-0075416f1b54ff6bd" "i-007f44f34c3333d9c"
#  [4] "i-0168a97df13f7162a" "i-01a4b33cbe8125a01" "i-020be99b4686b1b6f"
#  [7] "i-024c707b1450f4d53" "i-0281a5a962880d98e" "i-034ca80696bdf9e78"
# [10] "i-0352fef0691cda759" "i-03ce6d0f6fcb281f4" "i-040800b05979b298d"
# [13] "i-04afbb080c99db001" "i-04de8d0c4c390bf8a" "i-05fe13dec11abc13c"
# [16] "i-0682442ba5683bfea" "i-072bb0854930b685a" "i-07aa93ba5a3ea4b1e"
# [19] "i-07cd5a5faa8abfd40" "i-07ce5ba9adb5615c2" "i-07e5cc1d2f5f35a10"
# [22] "i-07ffd723ae2e21ba7" "i-08f5b61e0808c58b5" "i-08fbb95fa798c3cf5"
# [25] "i-0a04569906491d850" "i-0a2de5049514cfac3" "i-0a426c5eeebab75ac"
# [28] "i-0a5b65f93d99b84b0" "i-0a60ca37589d85ca8" "i-0b09b1e7b9a16c0aa"
# [31] "i-0b40a8969daeb7c26" "i-0b54bc86500ac883e" "i-0bd7d475981b23991"
# [34] "i-0c1f4e28cb91aa2e0" "i-0cb0ffdbe41cf02c9" "i-0cb612cf342d65eb5"
# [37] "i-0d9ea6a0cb4d96810" "i-0dc753ce793fb03af" "i-0dd7872ae4034cea6"
# ...

# %%
#Now bind the list of vm ids back into our dataframe
#pgbench <- cbind(pgbench, exp_ids)
sysbench <- sysbench[sysbench$instanceID != "",]
sysbench <- cbind(sysbench, vm_ids)

# %%
tail(sysbench)
# Out:
#       experimentID  setId instanceID          instanceType wallTime
# 11755 1573168503-47 47    i-0168a97df13f7162a m5d.large    7.174140
# 11756 1573168503-47 47    i-0168a97df13f7162a m5d.large    7.176353
# 11757 1573168503-47 47    i-0168a97df13f7162a m5d.large    7.177737
# 11758 1573168503-47 47    i-0168a97df13f7162a m5d.large    7.172229
# 11759 1573168503-47 47    i-0168a97df13f7162a m5d.large    7.173084
# 11760 1573168503-47 47    i-0168a97df13f7162a m5d.large    7.172506
#       testOption
# 11755 --test=cpu --cpu-max-prime=2000000 --num-threads=2 --max-requests=10 run
# 11756 --test=cpu --cpu-max-prime=2000000 --num-threads=2 --max-requests=10 run
# 11757 --test=cpu --cpu-max-prime=2000000 --num-threads=2 --max-requests=10 run
# 11758 --test=cpu --cpu-max-prime=2000000 --num-threads=2 --max-requests=10 run
# 11759 --test=cpu --cpu-max-prime=2000000 --num-threads=2 --max-requests=10 run
# 11760 --test=cpu --cpu-max-prime=2000000 --num-threads=2 --max-requests=10 run
# ...

# %%
#Looks like there is no missing data.
print(sysbench[sysbench$total.time == NA, ])
print(sysbench[sysbench$set.id == NA, ])
print(sysbench[sysbench$vm_ids == NA, ])
# Out:
#          experimentID setId instanceID instanceType wallTime testOption
# NA               <NA>    NA       <NA>         <NA>       NA       <NA>
# NA.1             <NA>    NA       <NA>         <NA>       NA       <NA>
# NA.2             <NA>    NA       <NA>         <NA>       NA       <NA>
# NA.3             <NA>    NA       <NA>         <NA>       NA       <NA>
# NA.4             <NA>    NA       <NA>         <NA>       NA       <NA>
# NA.5             <NA>    NA       <NA>         <NA>       NA       <NA>
# NA.6             <NA>    NA       <NA>         <NA>       NA       <NA>
# NA.7             <NA>    NA       <NA>         <NA>       NA       <NA>
# NA.8             <NA>    NA       <NA>         <NA>       NA       <NA>
# NA.9             <NA>    NA       <NA>         <NA>       NA       <NA>
# NA.10            <NA>    NA       <NA>         <NA>       NA       <NA>
# NA.11            <NA>    NA       <NA>         <NA>       NA       <NA>
# ...

# %%
#There are exactly as many observations as there should be: ((48 * (48 + 1)) / 2) * 10 = 11760
dim(sysbench)
# Out:
# [1] 11760    11

# %%
head(sysbench)
# Out:
#   experimentID setId instanceID          instanceType wallTime
# 1 1573168503-0 0     i-00425c78c8efcd2bd m5d.large    9.063212
# 2 1573168503-0 0     i-00425c78c8efcd2bd m5d.large    9.046827
# 3 1573168503-0 0     i-00425c78c8efcd2bd m5d.large    9.049040
# 4 1573168503-0 0     i-00425c78c8efcd2bd m5d.large    9.073480
# 5 1573168503-0 0     i-00425c78c8efcd2bd m5d.large    9.056286
# 6 1573168503-0 0     i-00425c78c8efcd2bd m5d.large    9.042144
#   testOption
# 1 --test=cpu --cpu-max-prime=2000000 --num-threads=2 --max-requests=10 run
# 2 --test=cpu --cpu-max-prime=2000000 --num-threads=2 --max-requests=10 run
# 3 --test=cpu --cpu-max-prime=2000000 --num-threads=2 --max-requests=10 run
# 4 --test=cpu --cpu-max-prime=2000000 --num-threads=2 --max-requests=10 run
# 5 --test=cpu --cpu-max-prime=2000000 --num-threads=2 --max-requests=10 run
# 6 --test=cpu --cpu-max-prime=2000000 --num-threads=2 --max-requests=10 run
#   per.request.avg.time total.time thread.num vm_ids vm_ids
# ...

# %%
#Write out the data we are interested in
sysbench = sysbench[c("total.time","setId","vm_ids")]
colnames(sysbench) <-c("sysbench","setId","vmId")
write.csv(sysbench,"./sysbench_standardized.csv",row.names = FALSE)
