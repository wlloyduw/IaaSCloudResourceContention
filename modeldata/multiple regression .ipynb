# %%
library(dplyr)
data<-read.csv("./merged.csv")
data
# Out:
#      iperf sysbench ycruncher pgbench  set vm
# 1    1158  8.4582   7.197     50637.00 1   1
# 2    1186  8.4469   7.193     53321.00 1   1
# 3    1201  8.4542   7.203     52701.00 1   1
# 4    1156  8.4596   7.198     52219.67 1   1
# 5    1167  8.4463   7.212     52219.67 1   1
# 6    1161  8.4477   7.211     52219.67 1   1
# 7    1158  8.4493   7.196     52219.67 1   1
# 8    1152  8.4705   7.188     52219.67 1   1
# 9    1158  8.4544   7.189     52219.67 1   1
# 10   1176  8.4503   7.215     52219.67 1   1
# 11   1149  8.4644   7.230     54518.00 2   1
# 12   1170  8.4529   7.219     54646.00 2   1
# 13   1198  8.4488   7.239     55194.00 2   1
# 14   1214  8.4478   7.212     54786.00 2   1
# 15   1155  8.4503   7.219     54786.00 2   1
# 16   1158  8.4529   7.226     54786.00 2   1
# 17   1158  8.4478   7.222     54786.00 2   1
# 18   1160  8.4675   7.238     54786.00 2   1
# 19   1158  8.4489   7.238     54786.00 2   1
# 20   1159  8.4491   7.219     54786.00 2   1
# ...

# %%
results = lm(data$set ~ data$iperf + data$sysbench + data$ycruncher)
summary(results)
# Out:
# Call:
# lm(formula = data$set ~ data$iperf + data$sysbench + data$ycruncher)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -8.030 -1.549 -0.116  1.437  6.249
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)    20.7501389 91.8608457   0.226    0.821
# data$iperf     -0.0080858  0.0003557 -22.734   <2e-16 ***
# data$sysbench  -6.9206068 10.8717359  -0.637    0.525
# data$ycruncher  7.4221648  0.2814752  26.369   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.288 on 1356 degrees of freedom
# Multiple R-squared:  0.6519,	Adjusted R-squared:  0.6511
# F-statistic: 846.5 on 3 and 1356 DF,  p-value: < 2.2e-16

# %%
par(mfrow=c(2,2))
plot(results)
# Out:
# Plot with title “”
