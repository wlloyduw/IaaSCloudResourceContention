# %%
library(dplyr)
library("ggpubr")
samples<-read.csv("./named/y_cruncher_dedicated_firstrun_No.15&No.16failed_labeled.csv")

# %%
set1=samples[samples$set==1,'computationTime']
result=c(range(set1),mean(set1),median(set1),var(set1))
result
# Out:
# [1] 7.33900000 7.87200000 7.49612857 7.50700000 0.01519079

# %%
ggboxplot(samples, x = "set", y = "computationTime", 
          color = "set", 
          ylab = "computationTime", xlab = "set")
# Out:
# plot without title

# %%
ggdensity(samples[,], x = "computationTime",
   add = "mean", rug = TRUE,
   color = "set", fill = "set",
   )
# Out:
# plot without title
