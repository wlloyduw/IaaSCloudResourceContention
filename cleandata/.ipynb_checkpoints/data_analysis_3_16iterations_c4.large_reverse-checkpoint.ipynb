# %%
library(dplyr)
library("ggpubr")
samples<-read.csv("./named/y_cruncher_dedicated_2ndrun_labeled.csv")

# %% [markdown]
# # 1.analyze set by set
# ### 1.1 description:
# set 1 contains 160 entrys generated from VM 1~16<br>
# set 2 contains 150 entrys generated from VM 2~16<br>
# .
# .
# .<br>
# set 16 contains 10 entrys generated from VM 16<br>
#
# each entry present 25,000,000digits*10runs of y-cruncher<br>

# %%
ggboxplot(samples, x = "set", y = "computationTime", 
          color = "set", 
          ylab = "computationTime", xlab = "set")
# Out:
# plot without title

# %% [markdown]
# ### 1.2 calculations on each set

# %%
statistic_result=data.frame()
for(i in 1:16){
    set=samples[samples$set==i,'computationTime']
    statistic_result=rbind(statistic_result,c(range(set),mean(set),median(set),var(set),i))
}
names(statistic_result)<-c('min','max','mean','median','var','set')
statistic_result
# Out:
#    min   max   mean     median var          set
# 1  7.483 9.823 7.664225 7.6390 6.036370e-02  1
# 2  7.361 7.807 7.575520 7.6485 2.034487e-02  2
# 3  7.302 7.803 7.571371 7.6505 2.678543e-02  3
# 4  7.273 7.753 7.559162 7.6460 2.820161e-02  4
# 5  7.243 7.780 7.545733 7.6425 3.394460e-02  5
# 6  7.216 7.747 7.546300 7.6345 3.292746e-02  6
# 7  7.224 7.459 7.363620 7.3980 5.909814e-03  7
# 8  7.215 7.417 7.320689 7.3370 3.077588e-03  8
# 9  7.179 7.421 7.317525 7.3415 4.569797e-03  9
# 10 7.164 7.414 7.328657 7.3465 4.204142e-03 10
# 11 7.326 7.406 7.359800 7.3560 4.292814e-04 11
# 12 7.275 7.343 7.310760 7.3105 2.765535e-04 12
# 13 7.237 7.311 7.276625 7.2770 3.159327e-04 13
# 14 7.212 7.289 7.252733 7.2495 4.451678e-04 14
# 15 7.218 7.250 7.235400 7.2380 1.406737e-04 15
# 16 7.189 7.216 7.204700 7.2045 5.445556e-05 16

# %%
ggplot(statistic_result, aes(x = set, y = mean, colour = set)) +
geom_line()
# Out:
# plot without title

# %% [markdown]
# ### 1.3 percentile

# %%
q=data.frame(quantile(samples$computationTime,c((1:10)/10)))
names(q)<-c('computationTime')
q
# Out:
#      computationTime
# 10%  7.2520
# 20%  7.3050
# 30%  7.3387
# 40%  7.3640
# 50%  7.4010
# 60%  7.5650
# 70%  7.6420
# 80%  7.6750
# 90%  7.7081
# 100% 9.8230

# %%
p<-data.frame(c((1:10)/10))
names(p)<-c('percentile')
q<-cbind(q,p)
q
# Out:
#      computationTime percentile
# 10%  7.2520          0.1
# 20%  7.3050          0.2
# 30%  7.3387          0.3
# 40%  7.3640          0.4
# 50%  7.4010          0.5
# 60%  7.5650          0.6
# 70%  7.6420          0.7
# 80%  7.6750          0.8
# 90%  7.7081          0.9
# 100% 9.8230          1.0

# %%
ggplot(q, aes(x =computationTime , y=percentile)) +
  geom_line()
# Out:
# plot without title

# %% [markdown]
# # 2. Another perspective - VM dimension

# %% [markdown]
# ### 2.1 VM No.16

# %%
samples<-samples[samples$vmID==16,]
ggboxplot(samples, x = "set", y = "computationTime", 
          color = "set", 
          ylab = "computationTime", xlab = "set")
# Out:
# plot without title

# %% [markdown]
# #### 2.1.1 statistic_result of VM No.16

# %%
statistic_result=data.frame()
for(i in 1:16){
    set=samples[samples$set==i,'computationTime']
    statistic_result=rbind(statistic_result,c(range(set),mean(set),median(set),var(set),i))
}
names(statistic_result)<-c('min','max','mean','median','var','set')
statistic_result
# Out:
#    min   max   mean   median var          set
# 1  7.634 7.726 7.6771 7.6800 1.009656e-03  1
# 2  7.647 7.769 7.6845 7.6770 1.314722e-03  2
# 3  7.641 7.800 7.7080 7.7105 1.920667e-03  3
# 4  7.638 7.717 7.6896 7.6980 8.187111e-04  4
# 5  7.619 7.740 7.6766 7.6615 1.369156e-03  5
# 6  7.615 7.728 7.6656 7.6575 1.017600e-03  6
# 7  7.398 7.445 7.4189 7.4225 2.352111e-04  7
# 8  7.348 7.390 7.3615 7.3610 1.345000e-04  8
# 9  7.338 7.369 7.3577 7.3610 1.284556e-04  9
# 10 7.324 7.371 7.3533 7.3505 1.844556e-04 10
# 11 7.341 7.376 7.3618 7.3625 1.175111e-04 11
# 12 7.305 7.334 7.3193 7.3200 1.002333e-04 12
# 13 7.245 7.293 7.2774 7.2800 2.007111e-04 13
# 14 7.225 7.285 7.2545 7.2540 2.869444e-04 14
# 15 7.218 7.242 7.2280 7.2250 8.422222e-05 15
# 16 7.189 7.216 7.2047 7.2045 5.445556e-05 16

# %%
ggplot(statistic_result, aes(x = set, y = mean, colour = set)) +
geom_line()
# Out:
# plot without title

# %%
(7.7-7.35)/7.35*100
(7.35-7.2)/7.2*100
# Out:
# [1] 4.761905
# [1] 2.083333

# %% [markdown]
# <i><b>I would say that there is visible CPU performance degradation(~5%) when host is above 50% utilization.

# %% [markdown]
# #### 2.1.2 percentile of VM No.16

# %%
q=data.frame(quantile(samples$computationTime,c((1:10)/10)))
names(q)<-c('computationTime')
q
# Out:
#      computationTime
# 10%  7.2259
# 20%  7.2776
# 30%  7.3275
# 40%  7.3550
# 50%  7.3660
# 60%  7.4260
# 70%  7.6516
# 80%  7.6740
# 90%  7.7093
# 100% 7.8000

# %%
p<-data.frame(c((1:10)/10))
names(p)<-c('percentile')
q<-cbind(q,p)
ggplot(q, aes(x =computationTime , y=percentile)) +
  geom_line()
# Out:
# plot without title

# %%
samples<-read.csv("./named/y_cruncher_dedicated_2ndrun_labeled.csv")
library(dplyr)
library("ggpubr")

# %%
ggplot(samples, aes(x = computationTime))+
geom_density(alpha = 0.3)
# Out:
# plot without title

# %%
ggplot(samples, aes(x = computationTime)) +
  geom_histogram(binwidth = 0.01, fill = "lightblue",)+
scale_x_continuous(breaks = scales::pretty_breaks(n = 20)) +
scale_y_continuous(breaks = scales::pretty_breaks(n = 10))
    #scale_x_continuous(breaks = round(seq(min(samples$computationTime), max(samples$computationTime), by = 0.3),1))
# Out:
# plot without title
