# %% [markdown]
# # Import data

# %%
library(dplyr)
library("ggpubr")
samples<-read.csv("./named/iperf_all/iperf_c4Client_c4Server_dedicatedhost_15s*11run.csv")

# %% [markdown]
# ## Network Test Description  Oct.24
# In that experiment, iperf act in the following way: Client establish a TCP connection to server, then server simultaneously connect back<br>
#
# - BandwidthUpload is measuring client -> server connection
# - BandwitdhDownload is mearsuring server -> client connection
# - C4 -> C4
# - 3runs -> 11runs

# %%
samples["bandwitdhDownload"] = as.numeric(gsub(" Mbits/sec","",unlist(samples["bandwitdhDownload"])))
samples["bandwidthUpload"] = as.numeric(gsub(" Mbits/sec","",unlist(samples["bandwidthUpload"])))
samples
# Out:
#      instanceID          instanceType experimentID interval bandwidthUpload
# 1    i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 582
# 2    i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 581
# 3    i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 558
# 4    i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 576
# 5    i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 571
# 6    i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 583
# 7    i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 582
# 8    i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 579
# 9    i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 572
# 10   i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 580
# 11   i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 562
# 12   i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 601
# 13   i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 566
# 14   i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 590
# 15   i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 570
# 16   i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 620
# 17   i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 584
# 18   i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 580
# 19   i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 579
# 20   i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 581
# 21   i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 579
# 22   i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 581
# 23   i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 554
# 24   i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 600
# 25   i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 564
# 26   i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 565
# 27   i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 596
# 28   i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 611
# 29   i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 595
# 30   i-0b48f4ebf89e2defd c4.large     1540409970   15.0 sec 608
# ⋮    ⋮                   ⋮            ⋮            ⋮        ⋮
# 1467 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 533
# 1468 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 135
# 1469 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 341
# 1470 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 635
# 1471 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 629
# 1472 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 596
# 1473 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 595
# 1474 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 599
# 1475 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 370
# 1476 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 399
# 1477 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 448
# 1478 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 435
# 1479 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 527
# 1480 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 479
# 1481 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 344
# 1482 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 377
# 1483 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 379
# 1484 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 349
# 1485 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 376
# 1486 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 575
# 1487 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 422
# 1488 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 321
# 1489 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 342
# 1490 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 387
# 1491 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 404
# 1492 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 457
# 1493 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 508
# 1494 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 506
# 1495 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 582
# 1496 i-05d786b38e32e0be3 c4.large     1540409970   15.0 sec 644
#      bandwitdhDownload setId vmId
# 1    577               1     1
# 2    577               1     1
# 3    628               1     1
# 4    625               1     1
# 5    585               1     1
# 6    584               1     1
# 7    579               1     1
# 8    579               1     1
# 9    580               1     1
# 10   578               1     1
# 11   614               1     1
# 12   605               2     1
# 13   583               2     1
# 14   580               2     1
# 15   628               2     1
# 16   594               2     1
# 17   571               2     1
# 18   578               2     1
# 19   579               2     1
# 20   579               2     1
# 21   579               2     1
# 22   578               2     1
# 23   631               3     1
# 24   580               3     1
# 25   569               3     1
# 26   586               3     1
# 27   551               3     1
# 28   582               3     1
# 29   617               3     1
# 30   601               3     1
# ⋮    ⋮                 ⋮     ⋮
# 1467 283               14    8
# 1468 358               14    8
# 1469 220               14    8
# 1470 284               14    8
# 1471 312               14    8
# 1472 250               14    8
# 1473 304               14    8
# 1474 308               14    8
# 1475 200               15    8
# 1476 184               15    8
# 1477 241               15    8
# 1478 216               15    8
# 1479 280               15    8
# 1480 368               15    8
# 1481 656               15    8
# 1482 611               15    8
# 1483 581               15    8
# 1484 547               15    8
# 1485 538               15    8
# 1486 159               16    8
# 1487 266               16    8
# 1488 269               16    8
# 1489 250               16    8
# 1490 442               16    8
# 1491 394               16    8
# 1492 320               16    8
# 1493 332               16    8
# 1494 297               16    8
# 1495 273               16    8
# 1496 262               16    8
#      cmd
# 1    iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 2    iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 3    iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 4    iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 5    iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 6    iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 7    iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 8    iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 9    iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 10   iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 11   iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 12   iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 13   iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 14   iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 15   iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 16   iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 17   iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 18   iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 19   iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 20   iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 21   iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 22   iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 23   iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 24   iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 25   iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 26   iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 27   iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 28   iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 29   iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# 30   iperf -c 34.201.166.149 --dualtest --window 416k --time 15
# ⋮    ⋮
# 1467 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1468 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1469 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1470 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1471 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1472 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1473 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1474 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1475 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1476 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1477 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1478 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1479 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1480 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1481 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1482 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1483 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1484 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1485 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1486 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1487 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1488 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1489 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1490 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1491 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1492 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1493 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1494 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1495 iperf -c 54.146.41.216 --dualtest --window 416k --time 15
# 1496 iperf -c 54.146.41.216 --dualtest --window 416k --time 15

# %% [markdown]
# # On column 'bandwidthDownload'

# %%
statistic_result=data.frame()

for(i in 1:16){
    thisSet=samples[samples$set==i,'bandwitdhDownload']
    statistic_result=rbind(statistic_result,c(range(thisSet),mean(thisSet),median(thisSet),var(thisSet),i))
}
names(statistic_result)<-c('min','max','mean','median','var','set')
statistic_result
ggplot(statistic_result, aes(x = set, y = mean, colour = set)) +
geom_line()
# Out:
#    min   max mean     median var        set
# 1  577.0 628 591.4545 580.0    410.6727  1
# 2  571.0 628 582.5909 579.0    148.0628  2
# 3  378.0 660 578.2727 579.0   1960.8920  3
# 4  549.0 619 580.0000 579.0    158.0000  4
# 5  403.0 616 578.2545 584.0   1319.4525  5
# 6  490.0 671 586.3485 592.0    985.8305  6
# 7  327.0 669 555.9221 590.0   6083.8096  7
# 8  177.0 670 475.2500 470.0  15316.6954  8
# 9  153.0 671 434.3333 363.0  17511.9184  9
# 10 147.0 672 407.6091 339.5  19979.8733 10
# 11 178.0 666 405.0826 345.0  19468.8598 11
# 12  88.4 670 387.7742 322.0  25424.0693 12
# 13 109.0 672 368.1049 318.0  23388.5734 13
# 14  57.1 665 325.4877 310.0  11792.9463 14
# 15  98.8 656 304.5624 278.0  11558.4564 15
# 16  89.6 572 300.6830 273.5   7214.2447 16
# plot without title

# %%
ggboxplot(samples, x = "setId", y = "bandwitdhDownload", 
          color = "setId", 
          ylab = "Download Mbits/sec", xlab = "setId",facet.by='vmId')
# Out:
# plot without title

# %% [markdown]
# # On column 'bandwidthUpload'

# %%
statistic_result=data.frame()

for(i in 1:16){
    thisSet=samples[samples$set==i,'bandwidthUpload']
    statistic_result=rbind(statistic_result,c(range(thisSet),mean(thisSet),median(thisSet),var(thisSet),i))
}
names(statistic_result)<-c('min','max','mean','median','var','set')
statistic_result
ggplot(statistic_result, aes(x = set, y = mean, colour = set)) +
geom_line()
# Out:
#    min   max mean     median var         set
# 1  558.0 583 575.0909 579.0     72.29091  1
# 2  566.0 620 582.5000 580.5    111.30952  2
# 3  425.0 667 578.7576 581.0   1899.25189  3
# 4  571.0 638 592.0000 584.0    243.30233  4
# 5  579.0 638 596.6000 592.0    246.65185  5
# 6  227.0 640 590.6212 595.0   2991.25431  6
# 7  297.0 670 586.3896 595.0   5033.31989  7
# 8  180.0 671 578.8068 595.0   7394.18064  8
# 9  191.0 671 592.7374 596.0   3770.80787  9
# 10 110.0 666 545.6091 595.0  16939.02927 10
# 11 269.0 672 560.1074 584.0   4910.33003 11
# 12 134.0 671 496.4621 485.0  11745.22756 12
# 13 114.0 673 482.4615 459.0  16111.03900 13
# 14  73.9 670 503.8110 547.0  19801.53929 14
# 15 106.0 673 480.1818 480.0  14653.03991 15
# 16  93.8 671 452.5614 443.5  14660.55301 16
# plot without title

# %%
ggboxplot(samples, x = "setId", y = "bandwidthUpload", 
          color = "setId", 
          ylab = "Upload Mbits/sec", xlab = "setId",facet.by='vmId')
# Out:
# plot without title

# %% [markdown]
# #  'bandwidthUpload + bandwidthDownload'

# %%
samples["cmd"] = samples["bandwidthUpload"] + samples["bandwitdhDownload"]

# %%
statistic_result=data.frame()

for(i in 1:16){
    thisSet=samples[samples$set==i,'cmd']
    statistic_result=rbind(statistic_result,c(range(thisSet),mean(thisSet),median(thisSet),var(thisSet),i))
}
names(statistic_result)<-c('min','max','mean','median','var','set')
statistic_result
ggplot(statistic_result, aes(x = set, y = mean, colour = set)) +
geom_line()
# Out:
#    min    max  mean      median var        set
# 1  1152.0 1201 1166.5455 1159.0   228.4727  1
# 2  1149.0 1214 1165.0909 1159.0   294.9437  2
# 3  1035.0 1212 1157.0303 1159.0  1620.9053  3
# 4  1149.0 1222 1172.0000 1163.5   370.8372  4
# 5   999.0 1249 1174.8545 1176.0  1536.4229  5
# 6   822.0 1262 1176.9697 1187.0  3394.7683  6
# 7   908.0 1245 1142.3117 1177.0  6707.1647  7
# 8   588.0 1243 1054.0568 1047.0 18136.3301  8
# 9   633.0 1246 1027.0707  987.0 18971.9031  9
# 10  309.0 1249  953.2182  925.5 36430.1905 10
# 11  640.0 1215  965.1901  947.0 20441.7052 11
# 12  235.4 1236  884.2364  915.0 38549.1987 12
# 13  409.0 1172  850.5664  915.0 31731.9375 13
# 14  284.9 1185  829.2987  882.0 30185.0763 14
# 15  367.0 1032  784.7442  822.0 24406.6418 15
# 16  349.8 1128  753.2443  766.5 18981.7432 16
# plot without title

# %%
ggboxplot(samples, x = "setId", y = "cmd", 
          color = "setId", 
          ylab = "upload + download Mbits/sec", xlab = "setId",facet.by='vmId')
# Out:
# plot without title

# %% [markdown]
# # Conclusion
#
# TODO:<br>
# upload + download = fairly fixed throughput -> from view of a single dedicated host<br>
# performance begin to drop from set8 and it's monotonically decreasing<br>
