# %% [markdown]
# ### import data

# %%
path = "./pgbench_16*c3.large_60s_1to16(reverse).csv"
NAMES <- read.table(path, nrow = 1, stringsAsFactors = FALSE, sep = ",")
DATA <- read.table(path, skip = 1, stringsAsFactors = FALSE, sep = ",")
names(DATA) <- NAMES 
data=DATA[,c('instanceID','wallTime','clients','threads','duration','transactions')]

# %% [markdown]
# ### sort instanceID by overall comutationTime

# %%
sum=aggregate(x=data["wallTime"],
          by=list(instanceID=DATA$instanceID),
          FUN=sum
         )
sorted=sum[order(sum$wallTime,decreasing=T),] 
sortedInstanceID=sorted$instanceID
sortedInstanceID
sorted
# Out:
#  [1] "i-0429db66a1a6e21c8" "i-003c9b18c0ea5d149" "i-0763518e62adde77a"
#  [4] "i-0b5ee2fbf4a7f182e" "i-0dda907af2bcf1f8d" "i-0b1703a8e3fe1f6c9"
#  [7] "i-08c6b31eb62575ff9" "i-0ab0d9ca12f000301" "i-0d738603054a00bd6"
# [10] "i-07594cd3a982b9904" "i-0d48e74939789e96c" "i-0178c009d34532fb3"
# [13] "i-0530876ca46f97dd4" "i-0d95d12b34f07f29b" "i-06950b814662ddbcc"
# [16] "i-0ca87c1c981dca37d"
#    instanceID          wallTime
# 3  i-0429db66a1a6e21c8 2890.9791
# 1  i-003c9b18c0ea5d149 2712.8168
# 7  i-0763518e62adde77a 2530.3985
# 11 i-0b5ee2fbf4a7f182e 2350.0644
# 16 i-0dda907af2bcf1f8d 2171.4818
# 10 i-0b1703a8e3fe1f6c9 1988.5061
# 8  i-08c6b31eb62575ff9 1808.6415
# 9  i-0ab0d9ca12f000301 1627.2729
# 14 i-0d738603054a00bd6 1446.8901
# 6  i-07594cd3a982b9904 1266.4239
# 13 i-0d48e74939789e96c 1084.9402
# 2  i-0178c009d34532fb3  904.3276
# 4  i-0530876ca46f97dd4  723.5281
# 15 i-0d95d12b34f07f29b  542.6251
# 5  i-06950b814662ddbcc  361.6948
# 12 i-0ca87c1c981dca37d  180.8620

# %%
runs=3

labeled=data[0:0,]
InstanceId=sortedInstanceID
n=length(InstanceId)
for(i in InstanceId){
    forthisInstance=data[data$instanceID==i,]
    offset=which(InstanceId==i)-1
    
    len=dim(forthisInstance)[1]/runs

    for(j in 1:len){
        x=(j-1)*runs+1
        y=(j*runs)
        
        tmp=data.frame(forthisInstance[x:y,],'set'=j+offset,'vmID'=len)
        
        labeled<-rbind(labeled,tmp) 
        
    }
}

# %%
labeled
# Out:
#     instanceID          wallTime clients threads duration transactions set vmID
# 112 i-0f606e5e5ebdf4d34 60.35096 10      10      60 s     50637         1  16
# 113 i-0f606e5e5ebdf4d34 60.18021 10      10      60 s     53321         1  16
# 114 i-0f606e5e5ebdf4d34 60.18666 10      10      60 s     52701         1  16
# 115 i-0f606e5e5ebdf4d34 60.22585 10      10      60 s     54518         2  16
# 116 i-0f606e5e5ebdf4d34 60.17822 10      10      60 s     54646         2  16
# 117 i-0f606e5e5ebdf4d34 60.18932 10      10      60 s     55194         2  16
# 118 i-0f606e5e5ebdf4d34 60.39861 10      10      60 s     56160         3  16
# 119 i-0f606e5e5ebdf4d34 60.17522 10      10      60 s     55132         3  16
# 120 i-0f606e5e5ebdf4d34 60.17683 10      10      60 s     55480         3  16
# 121 i-0f606e5e5ebdf4d34 60.24153 10      10      60 s     57630         4  16
# 122 i-0f606e5e5ebdf4d34 60.25207 10      10      60 s     57050         4  16
# 123 i-0f606e5e5ebdf4d34 60.22876 10      10      60 s     57607         4  16
# 124 i-0f606e5e5ebdf4d34 60.29138 10      10      60 s     54438         5  16
# 125 i-0f606e5e5ebdf4d34 60.23705 10      10      60 s     56672         5  16
# 126 i-0f606e5e5ebdf4d34 60.22222 10      10      60 s     56591         5  16
# 127 i-0f606e5e5ebdf4d34 60.23106 10      10      60 s     56428         6  16
# 128 i-0f606e5e5ebdf4d34 60.23276 10      10      60 s     56774         6  16
# 129 i-0f606e5e5ebdf4d34 60.24070 10      10      60 s     56835         6  16
# 130 i-0f606e5e5ebdf4d34 60.29543 10      10      60 s     54133         7  16
# 131 i-0f606e5e5ebdf4d34 60.26983 10      10      60 s     55861         7  16
# 132 i-0f606e5e5ebdf4d34 60.23581 10      10      60 s     54689         7  16
# 133 i-0f606e5e5ebdf4d34 60.22842 10      10      60 s     57623         8  16
# 134 i-0f606e5e5ebdf4d34 60.17791 10      10      60 s     57366         8  16
# 135 i-0f606e5e5ebdf4d34 60.20278 10      10      60 s     57438         8  16
# 136 i-0f606e5e5ebdf4d34 60.27194 10      10      60 s     57619         9  16
# 137 i-0f606e5e5ebdf4d34 60.19581 10      10      60 s     56115         9  16
# 138 i-0f606e5e5ebdf4d34 60.24895 10      10      60 s     58018         9  16
# 139 i-0f606e5e5ebdf4d34 60.18683 10      10      60 s     56960        10  16
# 140 i-0f606e5e5ebdf4d34 60.16904 10      10      60 s     57983        10  16
# 141 i-0f606e5e5ebdf4d34 60.17072 10      10      60 s     57139        10  16
# ⋮   ⋮                   ⋮        ⋮       ⋮       ⋮        ⋮            ⋮   ⋮
# 292 i-0d2400aba8caf34ec 60.81618 10      10      60 s     52321        13  4
# 293 i-0d2400aba8caf34ec 60.19547 10      10      60 s     53204        13  4
# 294 i-0d2400aba8caf34ec 60.19574 10      10      60 s     52978        13  4
# 295 i-0d2400aba8caf34ec 60.27745 10      10      60 s     53324        14  4
# 296 i-0d2400aba8caf34ec 60.19981 10      10      60 s     53505        14  4
# 297 i-0d2400aba8caf34ec 60.20163 10      10      60 s     52765        14  4
# 298 i-0d2400aba8caf34ec 60.34873 10      10      60 s     52852        15  4
# 299 i-0d2400aba8caf34ec 60.19369 10      10      60 s     53587        15  4
# 300 i-0d2400aba8caf34ec 60.20606 10      10      60 s     54085        15  4
# 301 i-0d2400aba8caf34ec 60.22283 10      10      60 s     53536        16  4
# 302 i-0d2400aba8caf34ec 60.20086 10      10      60 s     53553        16  4
# 303 i-0d2400aba8caf34ec 60.20934 10      10      60 s     53446        16  4
# 103 i-083b08549737f0346 60.32883 10      10      60 s     60751        14  3
# 104 i-083b08549737f0346 60.17705 10      10      60 s     60696        14  3
# 105 i-083b08549737f0346 60.22421 10      10      60 s     60481        14  3
# 106 i-083b08549737f0346 60.26902 10      10      60 s     57645        15  3
# 107 i-083b08549737f0346 60.18046 10      10      60 s     58391        15  3
# 108 i-083b08549737f0346 60.18494 10      10      60 s     59669        15  3
# 109 i-083b08549737f0346 60.18462 10      10      60 s     56618        16  3
# 110 i-083b08549737f0346 60.19208 10      10      60 s     58557        16  3
# 111 i-083b08549737f0346 60.19576 10      10      60 s     58341        16  3
# 160 i-085877eacd5f18029 60.29561 10      10      60 s     56562        15  2
# 161 i-085877eacd5f18029 60.18912 10      10      60 s     56810        15  2
# 162 i-085877eacd5f18029 60.18358 10      10      60 s     57631        15  2
# 163 i-085877eacd5f18029 60.18077 10      10      60 s     55818        16  2
# 164 i-085877eacd5f18029 60.21989 10      10      60 s     57201        16  2
# 165 i-085877eacd5f18029 60.18911 10      10      60 s     56890        16  2
# 379 i-08d2ea91c4c07a95d 60.34706 10      10      60 s     60283        16  1
# 380 i-08d2ea91c4c07a95d 60.15972 10      10      60 s     61217        16  1
# 381 i-08d2ea91c4c07a95d 60.16139 10      10      60 s     61148        16  1

# %% [markdown]
# # output labeled data

# %%
write.csv(labeled[1:8],"./labeled.csv")
